# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("cppTextData.txt",encoding="utf-8")
txtData = loader.load()
print(txtData[0])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from langchain_community.document_loaders import TextLoader
#       2 loader = TextLoader("cppTextData.txt",encoding="utf-8")
#       3 txtData = loader.load()
#       4 print(txtData[0])
#
# File <frozen importlib._bootstrap>:1431, in _handle_fromlist(module, fromlist, import_, recursive)
#    1428     if not recursive and hasattr(module, '__all__'):
#    1429         _handle_fromlist(module, module.__all__, import_,
#    1430                          recursive=True)
# -> 1431 elif not hasattr(module, x):
#    1432     from_name = f'{module.__name__}.{x}'
#    1433     try:
#
# File c:\GENA1\myen\Lib\site-packages\langchain_community\document_loaders\__init__.py:740, in __getattr__(name)
#     738 def __getattr__(name: str) -> Any:
#     739     if name in _module_lookup:
# ...

# %%
#Splitting Data / Chunks 
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size = 200, chunk_overlap = 20)
finalDocument = textSplitter.split_documents(txtData)
finalDocument

# %%
#data embedding means converting txt data into vectors
from langchain_huggingface import HuggingfaceEmbeddings
embedding = huggingFaceEmbeddings(model_name="all-MiniM-L6-v2")
